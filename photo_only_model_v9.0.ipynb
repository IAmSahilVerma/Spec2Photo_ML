# %%
import os
import json
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras import layers, callbacks, regularizers, models
from keras.models import load_model
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from util import save_history, save_model, plot_metrics, plot_visualizations

# %%
model_version = "v9.0"
base_model_version = 'v9.0'

# %%
seed_value = 42

os.environ['PYTHONHASHSEED'] = str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# %%
with open('data_schema.json', 'r') as f:
    config = json.load(f)
    
spectro_cols = config['spectro_cols']
photo_cols = config['photometry_cols']
generic_cols = config['generic_cols']
target_col = config['target_col']

# %%
df = pd.read_csv(f"data/processed/photometry_only.csv")

X = df[photo_cols + generic_cols]
y = df[target_col]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed_value)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
base_model = load_model(f'models/{base_model_version}/spec_photo_model.h5')

base_model.trainable = False

base_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 58)]              0
#
#  Dense_64 (Dense)            (None, 64)                3776
#
#  dropout (Dropout)           (None, 64)                0
#
#  Dense_128 (Dense)           (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  Dense_256 (Dense)           (None, 256)               33024
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  Dense_64_2 (Dense)          (None, 64)                16448
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 61,633
# Trainable params: 0
# Non-trainable params: 61,633
# _________________________________________________________________

# %%
input_shape = X_train_scaled.shape[1]
inputs = tf.keras.Input(shape=(input_shape,))
x = layers.Dense(64, activation='relu', name='new_input_layer')(inputs)

# ✅ Integrate base layers from index 2 onward
for layer in base_model.layers[2:]:
    x = layer(x)

# 🔧 Transfer head
x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001), name='Transfer_Dense_128')(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001), name='Transfer_Dense_64')(x)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(1)(x)

transfer_model = models.Model(inputs=inputs, outputs=outputs)
transfer_model.compile(optimizer=Adam(learning_rate=1e-4),
                       loss='mean_squared_error',
                       metrics=['mae', 'mse', 'mape'])

early_stopping = callbacks.EarlyStopping(monitor='val_loss',
                                         patience=30,
                                         restore_best_weights=True)

transfer_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 39)]              0
#
#  new_input_layer (Dense)     (None, 64)                2560
#
#  dropout (Dropout)           (None, 64)                0
#
#  Dense_128 (Dense)           (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  Dense_256 (Dense)           (None, 256)               33024
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  Dense_64_2 (Dense)          (None, 64)                16448
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 1)                 65
#
#  Transfer_Dense_128 (Dense)  (None, 128)               256
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  Transfer_Dense_64 (Dense)   (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 68,994
# Trainable params: 11,137
# Non-trainable params: 57,857
# _________________________________________________________________

# %%
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True,
    verbose=1
)
history = transfer_model.fit(X_train_scaled, y_train, epochs=200, batch_size=32, validation_split=0.2, verbose=1, callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 4467/4467 [==============================] - 30s 7ms/step - loss: 4.5255 - mae: 1.5878 - mse: 4.4613 - mape: 15.0176 - val_loss: 0.6141 - val_mae: 0.6896 - val_mse: 0.5555 - val_mape: 6.4790
# Epoch 2/200
# 4467/4467 [==============================] - 34s 8ms/step - loss: 2.3956 - mae: 1.2226 - mse: 2.3391 - mape: 11.5855 - val_loss: 0.4214 - val_mae: 0.5574 - val_mse: 0.3678 - val_mape: 5.2613
# Epoch 3/200
# 4467/4467 [==============================] - 54s 12ms/step - loss: 2.1086 - mae: 1.1448 - mse: 2.0589 - mape: 10.8532 - val_loss: 0.3436 - val_mae: 0.4931 - val_mse: 0.2979 - val_mape: 4.6609
# Epoch 4/200
# 4467/4467 [==============================] - 54s 12ms/step - loss: 1.8583 - mae: 1.0745 - mse: 1.8157 - mape: 10.1909 - val_loss: 0.2504 - val_mae: 0.3837 - val_mse: 0.2102 - val_mape: 3.6590
# Epoch 5/200
# 4467/4467 [==============================] - 52s 12ms/step - loss: 1.6067 - mae: 0.9972 - mse: 1.5680 - mape: 9.4683 - val_loss: 0.2089 - val_mae: 0.2986 - val_mse: 0.1714 - val_mape: 2.9038
# Epoch 6/200
# 4467/4467 [==============================] - 52s 12ms/step - loss: 1.3686 - mae: 0.9168 - mse: 1.3321 - mape: 8.7218 - val_loss: 0.2188 - val_mae: 0.2948 - val_mse: 0.1831 - val_mape: 2.8818
# Epoch 7/200
# 4467/4467 [==============================] - 52s 12ms/step - loss: 1.2005 - mae: 0.8552 - mse: 1.1653 - mape: 8.1447 - val_loss: 0.2549 - val_mae: 0.3672 - val_mse: 0.2199 - val_mape: 3.5218
# Epoch 8/200
# 4467/4467 [==============================] - 47s 11ms/step - loss: 1.0747 - mae: 0.8076 - mse: 1.0394 - mape: 7.6965 - val_loss: 0.1833 - val_mae: 0.2571 - val_mse: 0.1474 - val_mape: 2.5208
# Epoch 9/200
# 4467/4467 [==============================] - 48s 11ms/step - loss: 0.9761 - mae: 0.7671 - mse: 0.9401 - mape: 7.3021 - val_loss: 0.1638 - val_mae: 0.2531 - val_mse: 0.1286 - val_mape: 2.4669
# Epoch 10/200
# 4467/4467 [==============================] - 52s 12ms/step - loss: 0.9224 - mae: 0.7462 - mse: 0.8891 - mape: 7.1008 - val_loss: 0.1748 - val_mae: 0.2922 - val_mse: 0.1437 - val_mape: 2.8215
# Epoch 11/200
# 4467/4467 [==============================] - 50s 11ms/step - loss: 0.8834 - mae: 0.7314 - mse: 0.8540 - mape: 6.9612 - val_loss: 0.1299 - val_mae: 0.1777 - val_mse: 0.1021 - val_mape: 1.7845
# Epoch 12/200
# 4467/4467 [==============================] - 54s 12ms/step - loss: 0.8433 - mae: 0.7148 - mse: 0.8165 - mape: 6.8031 - val_loss: 0.1262 - val_mae: 0.1780 - val_mse: 0.1001 - val_mape: 1.7842
# Epoch 13/200
# 4467/4467 [==============================] - 49s 11ms/step - loss: 0.8129 - mae: 0.7014 - mse: 0.7876 - mape: 6.6773 - val_loss: 0.1385 - val_mae: 0.2354 - val_mse: 0.1139 - val_mape: 2.2982
# Epoch 14/200
# 4467/4467 [==============================] - 52s 12ms/step - loss: 0.7807 - mae: 0.6874 - mse: 0.7564 - mape: 6.5456 - val_loss: 0.1273 - val_mae: 0.2018 - val_mse: 0.1033 - val_mape: 1.9934
# Epoch 15/200
# 4467/4467 [==============================] - 52s 12ms/step - loss: 0.7553 - mae: 0.6753 - mse: 0.7315 - mape: 6.4310 - val_loss: 0.1186 - val_mae: 0.1653 - val_mse: 0.0950 - val_mape: 1.6670
# Epoch 16/200
# 4467/4467 [==============================] - 52s 12ms/step - loss: 0.7257 - mae: 0.6603 - mse: 0.7022 - mape: 6.2882 - val_loss: 0.1202 - val_mae: 0.1808 - val_mse: 0.0970 - val_mape: 1.8032
# Epoch 17/200
# 4467/4467 [==============================] - 52s 12ms/step - loss: 0.6962 - mae: 0.6465 - mse: 0.6729 - mape: 6.1590 - val_loss: 0.1457 - val_mae: 0.2629 - val_mse: 0.1224 - val_mape: 2.5474
# Epoch 18/200
# 4467/4467 [==============================] - 51s 11ms/step - loss: 0.6699 - mae: 0.6332 - mse: 0.6467 - mape: 6.0332 - val_loss: 0.1262 - val_mae: 0.2106 - val_mse: 0.1031 - val_mape: 2.0737
# Epoch 19/200
# 4467/4467 [==============================] - 50s 11ms/step - loss: 0.6439 - mae: 0.6203 - mse: 0.6208 - mape: 5.9134 - val_loss: 0.1248 - val_mae: 0.2069 - val_mse: 0.1016 - val_mape: 2.0387
# Epoch 20/200
# 4467/4467 [==============================] - 48s 11ms/step - loss: 0.6169 - mae: 0.6067 - mse: 0.5937 - mape: 5.7847 - val_loss: 0.1171 - val_mae: 0.1578 - val_mse: 0.0940 - val_mape: 1.6043
# Epoch 21/200
# 4467/4467 [==============================] - 51s 12ms/step - loss: 0.5908 - mae: 0.5920 - mse: 0.5677 - mape: 5.6460 - val_loss: 0.1402 - val_mae: 0.2512 - val_mse: 0.1172 - val_mape: 2.4397
# Epoch 22/200
# 4467/4467 [==============================] - 51s 11ms/step - loss: 0.5678 - mae: 0.5801 - mse: 0.5447 - mape: 5.5349 - val_loss: 0.1258 - val_mae: 0.2132 - val_mse: 0.1027 - val_mape: 2.0938
# Epoch 23/200
# 4467/4467 [==============================] - 52s 12ms/step - loss: 0.5452 - mae: 0.5672 - mse: 0.5222 - mape: 5.4116 - val_loss: 0.1224 - val_mae: 0.1985 - val_mse: 0.0993 - val_mape: 1.9624
# Epoch 24/200
# 4467/4467 [==============================] - 50s 11ms/step - loss: 0.5304 - mae: 0.5586 - mse: 0.5072 - mape: 5.3324 - val_loss: 0.1169 - val_mae: 0.1742 - val_mse: 0.0938 - val_mape: 1.7419
# Epoch 25/200
# 4467/4467 [==============================] - 53s 12ms/step - loss: 0.5076 - mae: 0.5447 - mse: 0.4846 - mape: 5.2010 - val_loss: 0.1193 - val_mae: 0.1893 - val_mse: 0.0962 - val_mape: 1.8777
# Epoch 26/200
# 4467/4467 [==============================] - 52s 12ms/step - loss: 0.4848 - mae: 0.5310 - mse: 0.4618 - mape: 5.0716 - val_loss: 0.1157 - val_mae: 0.1711 - val_mse: 0.0926 - val_mape: 1.7144
# Epoch 27/200
# 4467/4467 [==============================] - 51s 11ms/step - loss: 0.4678 - mae: 0.5205 - mse: 0.4448 - mape: 4.9743 - val_loss: 0.1292 - val_mae: 0.2275 - val_mse: 0.1060 - val_mape: 2.2236
# Epoch 28/200
# 4467/4467 [==============================] - 36s 8ms/step - loss: 0.4517 - mae: 0.5100 - mse: 0.4286 - mape: 4.8736 - val_loss: 0.1163 - val_mae: 0.1778 - val_mse: 0.0931 - val_mape: 1.7733
# Epoch 29/200
# 4467/4467 [==============================] - 30s 7ms/step - loss: 0.4341 - mae: 0.4997 - mse: 0.4110 - mape: 4.7767 - val_loss: 0.1215 - val_mae: 0.1980 - val_mse: 0.0985 - val_mape: 1.9575
# Epoch 30/200
# 4467/4467 [==============================] - 30s 7ms/step - loss: 0.4182 - mae: 0.4882 - mse: 0.3951 - mape: 4.6709 - val_loss: 0.1168 - val_mae: 0.1867 - val_mse: 0.0934 - val_mape: 1.8538
# Epoch 31/200
# 4467/4467 [==============================] - 30s 7ms/step - loss: 0.4003 - mae: 0.4765 - mse: 0.3771 - mape: 4.5576 - val_loss: 0.1178 - val_mae: 0.1841 - val_mse: 0.0947 - val_mape: 1.8302
# Epoch 32/200
# 4467/4467 [==============================] - 30s 7ms/step - loss: 0.3859 - mae: 0.4659 - mse: 0.3627 - mape: 4.4603 - val_loss: 0.1225 - val_mae: 0.2061 - val_mse: 0.0993 - val_mape: 2.0281
# Epoch 33/200
# 4467/4467 [==============================] - 30s 7ms/step - loss: 0.3704 - mae: 0.4559 - mse: 0.3472 - mape: 4.3656 - val_loss: 0.1165 - val_mae: 0.1801 - val_mse: 0.0934 - val_mape: 1.7940
# Epoch 34/200
# 4467/4467 [==============================] - 30s 7ms/step - loss: 0.3560 - mae: 0.4450 - mse: 0.3328 - mape: 4.2638 - val_loss: 0.1170 - val_mae: 0.1818 - val_mse: 0.0940 - val_mape: 1.8083
# Epoch 35/200
# 4467/4467 [==============================] - 30s 7ms/step - loss: 0.3449 - mae: 0.4361 - mse: 0.3218 - mape: 4.1803 - val_loss: 0.1165 - val_mae: 0.1816 - val_mse: 0.0933 - val_mape: 1.8085
# Epoch 36/200
# 4467/4467 [==============================] - 30s 7ms/step - loss: 0.3321 - mae: 0.4262 - mse: 0.3090 - mape: 4.0878 - val_loss: 0.1146 - val_mae: 0.1701 - val_mse: 0.0916 - val_mape: 1.7047
# Epoch 37/200
# 4467/4467 [==============================] - 30s 7ms/step - loss: 0.3189 - mae: 0.4163 - mse: 0.2958 - mape: 3.9945 - val_loss: 0.1192 - val_mae: 0.1958 - val_mse: 0.0961 - val_mape: 1.9372
# Epoch 38/200
# 4467/4467 [==============================] - 29s 7ms/step - loss: 0.3086 - mae: 0.4076 - mse: 0.2856 - mape: 3.9132 - val_loss: 0.1130 - val_mae: 0.1708 - val_mse: 0.0898 - val_mape: 1.7079
# Epoch 39/200
# 4467/4467 [==============================] - 30s 7ms/step - loss: 0.2975 - mae: 0.3994 - mse: 0.2745 - mape: 3.8349 - val_loss: 0.1159 - val_mae: 0.1808 - val_mse: 0.0932 - val_mape: 1.7997
# Epoch 40/200
# 4467/4467 [==============================] - 30s 7ms/step - loss: 0.2884 - mae: 0.3909 - mse: 0.2657 - mape: 3.7558 - val_loss: 0.1122 - val_mae: 0.1559 - val_mse: 0.0896 - val_mape: 1.5769
# Epoch 41/200
# 4467/4467 [==============================] - 30s 7ms/step - loss: 0.2794 - mae: 0.3837 - mse: 0.2568 - mape: 3.6877 - val_loss: 0.1158 - val_mae: 0.1832 - val_mse: 0.0933 - val_mape: 1.8227
# Epoch 42/200
# 4467/4467 [==============================] - 29s 7ms/step - loss: 0.2714 - mae: 0.3763 - mse: 0.2488 - mape: 3.6187 - val_loss: 0.1182 - val_mae: 0.1954 - val_mse: 0.0959 - val_mape: 1.9305
# Epoch 43/200
# 4467/4467 [==============================] - 29s 7ms/step - loss: 0.2631 - mae: 0.3696 - mse: 0.2408 - mape: 3.5555 - val_loss: 0.1093 - val_mae: 0.1494 - val_mse: 0.0869 - val_mape: 1.5176
# Epoch 44/200
# 4467/4467 [==============================] - 29s 7ms/step - loss: 0.2542 - mae: 0.3611 - mse: 0.2320 - mape: 3.4759 - val_loss: 0.1136 - val_mae: 0.1824 - val_mse: 0.0915 - val_mape: 1.8114
# Epoch 45/200
# 4467/4467 [==============================] - 30s 7ms/step - loss: 0.2462 - mae: 0.3538 - mse: 0.2242 - mape: 3.4071 - val_loss: 0.1088 - val_mae: 0.1617 - val_mse: 0.0868 - val_mape: 1.6244
# Epoch 46/200
# 4467/4467 [==============================] - 30s 7ms/step - loss: 0.2401 - mae: 0.3485 - mse: 0.2183 - mape: 3.3580 - val_loss: 0.1144 - val_mae: 0.1865 - val_mse: 0.0930 - val_mape: 1.8475
# Epoch 47/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.2338 - mae: 0.3426 - mse: 0.2123 - mape: 3.3028 - val_loss: 0.1081 - val_mae: 0.1474 - val_mse: 0.0868 - val_mape: 1.5001
# Epoch 48/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.2273 - mae: 0.3367 - mse: 0.2061 - mape: 3.2469 - val_loss: 0.1103 - val_mae: 0.1767 - val_mse: 0.0891 - val_mape: 1.7597
# Epoch 49/200
# 4467/4467 [==============================] - 38s 8ms/step - loss: 0.2221 - mae: 0.3316 - mse: 0.2011 - mape: 3.1991 - val_loss: 0.1069 - val_mae: 0.1495 - val_mse: 0.0862 - val_mape: 1.5173
# Epoch 50/200
# 4467/4467 [==============================] - 38s 8ms/step - loss: 0.2175 - mae: 0.3267 - mse: 0.1969 - mape: 3.1533 - val_loss: 0.1063 - val_mae: 0.1567 - val_mse: 0.0857 - val_mape: 1.5779
# Epoch 51/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.2130 - mae: 0.3223 - mse: 0.1926 - mape: 3.1119 - val_loss: 0.1104 - val_mae: 0.1803 - val_mse: 0.0902 - val_mape: 1.7914
# Epoch 52/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.2083 - mae: 0.3178 - mse: 0.1882 - mape: 3.0693 - val_loss: 0.1044 - val_mae: 0.1529 - val_mse: 0.0844 - val_mape: 1.5435
# Epoch 53/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.2038 - mae: 0.3135 - mse: 0.1840 - mape: 3.0286 - val_loss: 0.1058 - val_mae: 0.1649 - val_mse: 0.0861 - val_mape: 1.6521
# Epoch 54/200
# 4467/4467 [==============================] - 36s 8ms/step - loss: 0.2001 - mae: 0.3091 - mse: 0.1805 - mape: 2.9885 - val_loss: 0.1051 - val_mae: 0.1440 - val_mse: 0.0856 - val_mape: 1.4699
# Epoch 55/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1966 - mae: 0.3058 - mse: 0.1772 - mape: 2.9569 - val_loss: 0.1063 - val_mae: 0.1658 - val_mse: 0.0872 - val_mape: 1.6593
# Epoch 56/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1918 - mae: 0.3014 - mse: 0.1727 - mape: 2.9151 - val_loss: 0.1044 - val_mae: 0.1665 - val_mse: 0.0854 - val_mape: 1.6657
# Epoch 57/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1892 - mae: 0.2983 - mse: 0.1703 - mape: 2.8869 - val_loss: 0.1034 - val_mae: 0.1432 - val_mse: 0.0847 - val_mape: 1.4602
# Epoch 58/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1870 - mae: 0.2959 - mse: 0.1683 - mape: 2.8647 - val_loss: 0.1029 - val_mae: 0.1509 - val_mse: 0.0843 - val_mape: 1.5256
# Epoch 59/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1854 - mae: 0.2938 - mse: 0.1669 - mape: 2.8459 - val_loss: 0.1054 - val_mae: 0.1711 - val_mse: 0.0869 - val_mape: 1.7075
# Epoch 60/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1825 - mae: 0.2900 - mse: 0.1642 - mape: 2.8101 - val_loss: 0.1022 - val_mae: 0.1606 - val_mse: 0.0838 - val_mape: 1.6116
# Epoch 61/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1807 - mae: 0.2884 - mse: 0.1624 - mape: 2.7949 - val_loss: 0.1020 - val_mae: 0.1410 - val_mse: 0.0838 - val_mape: 1.4410
# Epoch 62/200
# 4467/4467 [==============================] - 38s 8ms/step - loss: 0.1792 - mae: 0.2865 - mse: 0.1611 - mape: 2.7774 - val_loss: 0.1015 - val_mae: 0.1483 - val_mse: 0.0834 - val_mape: 1.5029
# Epoch 63/200
# 4467/4467 [==============================] - 38s 8ms/step - loss: 0.1773 - mae: 0.2848 - mse: 0.1593 - mape: 2.7621 - val_loss: 0.1002 - val_mae: 0.1516 - val_mse: 0.0822 - val_mape: 1.5298
# Epoch 64/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1756 - mae: 0.2830 - mse: 0.1577 - mape: 2.7448 - val_loss: 0.1024 - val_mae: 0.1554 - val_mse: 0.0847 - val_mape: 1.5654
# Epoch 65/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1744 - mae: 0.2814 - mse: 0.1567 - mape: 2.7307 - val_loss: 0.1029 - val_mae: 0.1633 - val_mse: 0.0853 - val_mape: 1.6360
# Epoch 66/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1735 - mae: 0.2806 - mse: 0.1559 - mape: 2.7236 - val_loss: 0.1023 - val_mae: 0.1605 - val_mse: 0.0848 - val_mape: 1.6124
# Epoch 67/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1722 - mae: 0.2784 - mse: 0.1547 - mape: 2.7036 - val_loss: 0.1011 - val_mae: 0.1461 - val_mse: 0.0837 - val_mape: 1.4850
# Epoch 68/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1718 - mae: 0.2780 - mse: 0.1544 - mape: 2.7005 - val_loss: 0.1029 - val_mae: 0.1572 - val_mse: 0.0856 - val_mape: 1.5847
# Epoch 69/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1709 - mae: 0.2769 - mse: 0.1537 - mape: 2.6909 - val_loss: 0.1039 - val_mae: 0.1695 - val_mse: 0.0867 - val_mape: 1.6947
# Epoch 70/200
# 4467/4467 [==============================] - 38s 8ms/step - loss: 0.1699 - mae: 0.2759 - mse: 0.1527 - mape: 2.6811 - val_loss: 0.1031 - val_mae: 0.1631 - val_mse: 0.0860 - val_mape: 1.6372
# Epoch 71/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1705 - mae: 0.2762 - mse: 0.1535 - mape: 2.6852 - val_loss: 0.1007 - val_mae: 0.1498 - val_mse: 0.0836 - val_mape: 1.5166
# Epoch 72/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1690 - mae: 0.2745 - mse: 0.1521 - mape: 2.6692 - val_loss: 0.1024 - val_mae: 0.1605 - val_mse: 0.0854 - val_mape: 1.6141
# Epoch 73/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1692 - mae: 0.2749 - mse: 0.1523 - mape: 2.6729 - val_loss: 0.1020 - val_mae: 0.1466 - val_mse: 0.0851 - val_mape: 1.4917
# Epoch 74/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1684 - mae: 0.2740 - mse: 0.1516 - mape: 2.6647 - val_loss: 0.1006 - val_mae: 0.1489 - val_mse: 0.0839 - val_mape: 1.5115
# Epoch 75/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1691 - mae: 0.2741 - mse: 0.1524 - mape: 2.6667 - val_loss: 0.1004 - val_mae: 0.1468 - val_mse: 0.0837 - val_mape: 1.4924
# Epoch 76/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1677 - mae: 0.2727 - mse: 0.1511 - mape: 2.6537 - val_loss: 0.1050 - val_mae: 0.1694 - val_mse: 0.0884 - val_mape: 1.6972
# Epoch 77/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1678 - mae: 0.2732 - mse: 0.1513 - mape: 2.6585 - val_loss: 0.1029 - val_mae: 0.1526 - val_mse: 0.0864 - val_mape: 1.5456
# Epoch 78/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1679 - mae: 0.2726 - mse: 0.1514 - mape: 2.6525 - val_loss: 0.1050 - val_mae: 0.1692 - val_mse: 0.0886 - val_mape: 1.6932
# Epoch 79/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1675 - mae: 0.2724 - mse: 0.1510 - mape: 2.6514 - val_loss: 0.1003 - val_mae: 0.1492 - val_mse: 0.0839 - val_mape: 1.5143
# Epoch 80/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1676 - mae: 0.2728 - mse: 0.1512 - mape: 2.6547 - val_loss: 0.1031 - val_mae: 0.1603 - val_mse: 0.0867 - val_mape: 1.6135
# Epoch 81/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1674 - mae: 0.2723 - mse: 0.1510 - mape: 2.6496 - val_loss: 0.1032 - val_mae: 0.1637 - val_mse: 0.0868 - val_mape: 1.6471
# Epoch 82/200
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1674 - mae: 0.2728 - mse: 0.1511 - mape: 2.6545 - val_loss: 0.1008 - val_mae: 0.1512 - val_mse: 0.0845 - val_mape: 1.5321
# Epoch 83/200
# 4461/4467 [============================>.] - ETA: 0s - loss: 0.1676 - mae: 0.2726 - mse: 0.1513 - mape: 2.6531Restoring model weights from the end of the best epoch: 63.
# 4467/4467 [==============================] - 37s 8ms/step - loss: 0.1676 - mae: 0.2726 - mse: 0.1513 - mape: 2.6533 - val_loss: 0.1007 - val_mae: 0.1442 - val_mse: 0.0844 - val_mape: 1.4717
# Epoch 83: early stopping

# %%
y_pred = transfer_model.predict(X_test_scaled)
# Out:
# 1396/1396 [==============================] - 3s 2ms/step

# %%
plot_metrics(y_test, y_pred)
# Out:
# Evaluation Metrics:
# Mean Absolute Error (MAE): 0.1537
# Root Mean Squared Error (RMSE): 0.2941
# R² Score: 0.8014

# %%
plot_visualizations(history, y_test, y_pred)

# %%
def save_model(model, model_version, model_name='spec_photo_model'):
    os.makedirs(f'models/{model_version}', exist_ok=True)
    model.save(f'models/{model_version}/{model_name}.h5')
    
def save_history(history, model_version, history_name='history'):
    os.makedirs(f'history/{model_version}', exist_ok=True)

    history_path = os.path.join(f'history/{model_version}', f'{history_name}.json')
    with open(history_path, 'w') as f:
        json.dump(history.history, f)

# %%
save_history(history, model_version, 'history_photo_only')

# %%
save_model(transfer_model, model_version, 'photo_only_model')
