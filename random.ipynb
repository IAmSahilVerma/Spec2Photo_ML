# %%
import pandas as pd

df = pd.read_csv('./data/raw/combined.csv')
df
# Out:
#                   specObjID            bestObjID         z      zErr  \
# 0       2413991036171872256  1237665548892635380  0.227420  0.000030
# 1       1129339498400868352  1237658299536965763  0.071281  0.000017
# 2        570901386112296960  1237648722833637574  0.038903  0.000013
# 3       1608983584809445376  1237660635458437274  0.352862  0.000074
# 4        987483252132440064  1237657856068813503  0.467755  0.000200
# ...                     ...                  ...       ...       ...
# 913852  1517794764903180288  1237661871339339969  0.117228  0.000030
# 913853  2033521526514411520  1237661948654125074  0.130395  0.000046
# 913854   568667177880676352  1237651736284037404  0.181179  0.000039
# 913855   441527615912699904  1237663716018815035  0.041375  0.000008
# 913856  1085520386705090560  1237658613054177372  0.109069  0.000015
#
#         zWarning   class     subClass         ra        dec  plate  ...  \
# ...
