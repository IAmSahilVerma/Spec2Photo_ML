# %%
import sys
sys.path.append('../')

# %%
import os
import json
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras import layers, callbacks, regularizers
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from util import save_history, save_model, plot_metrics, plot_visualizations

# %%
seed_value = 42

os.environ['PYTHONHASHSEED'] = str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# %%
model_version = 'v13.0'

# %%
with open('../data_schema.json', 'r') as f:
    config = json.load(f)
    
spectro_cols = config['spectro_cols']
photo_cols = config['photometry_cols']
generic_cols = config['generic_cols']
target_col = config['target_col']

# %%
df = pd.read_csv(f"../data/processed/spectrometry_photometry.csv")

X = df[spectro_cols + photo_cols + generic_cols]
y = df[target_col]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed_value)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
input_shape = X_train_scaled.shape[1]

optimizer = Adam(learning_rate=0.001)

inputs = keras.Input(shape=(input_shape,), name='Input')

# Layer 1
x = layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), name='Dense_32')(inputs)
x = layers.Activation('relu', name='Act_32')(x)
x = layers.Dropout(0.2, name='Dropout_32')(x)

# Layer 2
x = layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), name='Dense_64')(x)
x = layers.Activation('relu', name='Act_64')(x)
x = layers.Dropout(0.2, name='Dropout_64')(x)

# Layer 3
x = layers.Dense(128, kernel_regularizer=regularizers.l2(0.001), name='Dense_128')(x)
x = layers.Activation('relu', name='Act_128')(x)
x = layers.Dropout(0.2, name='Dropout_128')(x)

# Layer 4
x = layers.Dense(256, kernel_regularizer=regularizers.l2(0.001), name='Dense_256')(x)
x = layers.Activation('relu', name='Act_256')(x)
x = layers.Dropout(0.2, name='Dropout_256')(x)

# Layer 5
x = layers.Dense(128, kernel_regularizer=regularizers.l2(0.001), name='Dense_128_2')(x)
x = layers.Activation('relu', name='Act_128_2')(x)
x = layers.Dropout(0.2, name='Dropout_128_2')(x)

# Layer 6
x = layers.Dense(128, kernel_regularizer=regularizers.l2(0.001), name='Dense_64_2')(x)
x = layers.Activation('relu', name='Act_64_2')(x)
x = layers.Dropout(0.2, name='Dropout_64_2')(x)

# Layer 7
x = layers.Dense(128, kernel_regularizer=regularizers.l2(0.001), name='Dense_32_2')(x)
x = layers.Activation('relu', name='Act_32_2')(x)
x = layers.Dropout(0.2, name='Dropout_32_2')(x)

# Output layer
outputs = layers.Dense(1, name='Output')(x)

model = keras.Model(inputs=inputs, outputs=outputs, name='Regression_Model')
early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# Use Huber loss to balance sensitivity to outliers
model.compile(optimizer=optimizer, 
              loss=tf.keras.losses.mean_absolute_error, 
              metrics=['mae', 'mse', 'mape'])

model.summary()
# Out:
# Model: "Regression_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 58)]              0
#
#  Dense_32 (Dense)            (None, 64)                3776
#
#  Act_32 (Activation)         (None, 64)                0
#
#  Dropout_32 (Dropout)        (None, 64)                0
#
#  Dense_64 (Dense)            (None, 64)                4160
#
#  Act_64 (Activation)         (None, 64)                0
#
#  Dropout_64 (Dropout)        (None, 64)                0
#
#  Dense_128 (Dense)           (None, 128)               8320
#
#  Act_128 (Activation)        (None, 128)               0
#
#  Dropout_128 (Dropout)       (None, 128)               0
#
#  Dense_256 (Dense)           (None, 256)               33024
#
#  Act_256 (Activation)        (None, 256)               0
#
#  Dropout_256 (Dropout)       (None, 256)               0
#
#  Dense_128_2 (Dense)         (None, 128)               32896
#
#  Act_128_2 (Activation)      (None, 128)               0
#
#  Dropout_128_2 (Dropout)     (None, 128)               0
#
#  Dense_64_2 (Dense)          (None, 128)               16512
#
#  Act_64_2 (Activation)       (None, 128)               0
#
#  Dropout_64_2 (Dropout)      (None, 128)               0
#
#  Dense_32_2 (Dense)          (None, 128)               16512
#
#  Act_32_2 (Activation)       (None, 128)               0
#
#  Dropout_32_2 (Dropout)      (None, 128)               0
#
#  Output (Dense)              (None, 1)                 129
#
# =================================================================
# Total params: 115,329
# Trainable params: 115,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    X_train_scaled, y_train,
    validation_split=0.5,
    epochs=200,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/200
# 2443/2443 [==============================] - 22s 9ms/step - loss: 1.2260 - mae: 0.8868 - mse: 3.1912 - mape: 8.4350 - val_loss: 0.3904 - val_mae: 0.2135 - val_mse: 0.0807 - val_mape: 2.0455
# Epoch 2/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.6702 - mae: 0.5704 - mse: 0.5217 - mape: 5.4190 - val_loss: 0.1974 - val_mae: 0.1487 - val_mse: 0.0520 - val_mape: 1.4507
# Epoch 3/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.5441 - mae: 0.5125 - mse: 0.4215 - mape: 4.8716 - val_loss: 0.1739 - val_mae: 0.1515 - val_mse: 0.0637 - val_mape: 1.5201
# Epoch 4/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.5052 - mae: 0.4850 - mse: 0.3788 - mape: 4.6186 - val_loss: 0.1963 - val_mae: 0.1774 - val_mse: 0.0642 - val_mape: 1.7094
# Epoch 5/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.4800 - mae: 0.4616 - mse: 0.3464 - mape: 4.3983 - val_loss: 0.2022 - val_mae: 0.1836 - val_mse: 0.0656 - val_mape: 1.7891
# Epoch 6/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.4574 - mae: 0.4392 - mse: 0.3131 - mape: 4.1852 - val_loss: 0.1913 - val_mae: 0.1733 - val_mse: 0.0621 - val_mape: 1.6831
# Epoch 7/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.4370 - mae: 0.4189 - mse: 0.2867 - mape: 3.9946 - val_loss: 0.1494 - val_mae: 0.1309 - val_mse: 0.0531 - val_mape: 1.3027
# Epoch 8/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.4135 - mae: 0.3947 - mse: 0.2553 - mape: 3.7634 - val_loss: 0.1537 - val_mae: 0.1339 - val_mse: 0.0434 - val_mape: 1.3096
# Epoch 9/200
# 2443/2443 [==============================] - 21s 9ms/step - loss: 0.3890 - mae: 0.3694 - mse: 0.2264 - mape: 3.5226 - val_loss: 0.2241 - val_mae: 0.2047 - val_mse: 0.0707 - val_mape: 1.9472
# Epoch 10/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.3715 - mae: 0.3516 - mse: 0.2056 - mape: 3.3535 - val_loss: 0.1534 - val_mae: 0.1334 - val_mse: 0.0479 - val_mape: 1.3178
# Epoch 11/200
# 2443/2443 [==============================] - 21s 8ms/step - loss: 0.3527 - mae: 0.3325 - mse: 0.1865 - mape: 3.1768 - val_loss: 0.1362 - val_mae: 0.1157 - val_mse: 0.0399 - val_mape: 1.1460
# Epoch 12/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.3307 - mae: 0.3099 - mse: 0.1638 - mape: 2.9629 - val_loss: 0.1360 - val_mae: 0.1151 - val_mse: 0.0379 - val_mape: 1.1411
# Epoch 13/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.3147 - mae: 0.2936 - mse: 0.1485 - mape: 2.8103 - val_loss: 0.1950 - val_mae: 0.1742 - val_mse: 0.0545 - val_mape: 1.6693
# Epoch 14/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.2965 - mae: 0.2748 - mse: 0.1328 - mape: 2.6339 - val_loss: 0.1341 - val_mae: 0.1116 - val_mse: 0.0355 - val_mape: 1.1027
# Epoch 15/200
# 2443/2443 [==============================] - 21s 8ms/step - loss: 0.2810 - mae: 0.2589 - mse: 0.1205 - mape: 2.4840 - val_loss: 0.2093 - val_mae: 0.1879 - val_mse: 0.0687 - val_mape: 1.8180
# Epoch 16/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.2659 - mae: 0.2431 - mse: 0.1085 - mape: 2.3379 - val_loss: 0.1438 - val_mae: 0.1208 - val_mse: 0.0467 - val_mape: 1.2096
# Epoch 17/200
# 2443/2443 [==============================] - 21s 8ms/step - loss: 0.2518 - mae: 0.2286 - mse: 0.0986 - mape: 2.2012 - val_loss: 0.1350 - val_mae: 0.1120 - val_mse: 0.0411 - val_mape: 1.1174
# Epoch 18/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.2396 - mae: 0.2161 - mse: 0.0897 - mape: 2.0830 - val_loss: 0.1448 - val_mae: 0.1213 - val_mse: 0.0382 - val_mape: 1.1921
# Epoch 19/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.2266 - mae: 0.2024 - mse: 0.0821 - mape: 1.9560 - val_loss: 0.1295 - val_mae: 0.1053 - val_mse: 0.0376 - val_mape: 1.0532
# Epoch 20/200
# 2443/2443 [==============================] - 21s 8ms/step - loss: 0.2183 - mae: 0.1937 - mse: 0.0782 - mape: 1.8770 - val_loss: 0.1455 - val_mae: 0.1209 - val_mse: 0.0377 - val_mape: 1.1766
# Epoch 21/200
# 2443/2443 [==============================] - 21s 8ms/step - loss: 0.2084 - mae: 0.1835 - mse: 0.0729 - mape: 1.7836 - val_loss: 0.1237 - val_mae: 0.0986 - val_mse: 0.0347 - val_mape: 0.9832
# Epoch 22/200
# 2443/2443 [==============================] - 21s 9ms/step - loss: 0.2025 - mae: 0.1775 - mse: 0.0720 - mape: 1.7318 - val_loss: 0.1290 - val_mae: 0.1035 - val_mse: 0.0363 - val_mape: 1.0304
# Epoch 23/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.1990 - mae: 0.1738 - mse: 0.0725 - mape: 1.7022 - val_loss: 0.1199 - val_mae: 0.0944 - val_mse: 0.0384 - val_mape: 0.9530
# Epoch 24/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.1958 - mae: 0.1708 - mse: 0.0723 - mape: 1.6781 - val_loss: 0.1419 - val_mae: 0.1174 - val_mse: 0.0452 - val_mape: 1.1670
# Epoch 25/200
# 2443/2443 [==============================] - 21s 8ms/step - loss: 0.1950 - mae: 0.1705 - mse: 0.0732 - mape: 1.6784 - val_loss: 0.1335 - val_mae: 0.1095 - val_mse: 0.0468 - val_mape: 1.1015
# Epoch 26/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.1937 - mae: 0.1695 - mse: 0.0734 - mape: 1.6718 - val_loss: 0.1437 - val_mae: 0.1196 - val_mse: 0.0512 - val_mape: 1.2091
# Epoch 27/200
# 2443/2443 [==============================] - 21s 8ms/step - loss: 0.1936 - mae: 0.1698 - mse: 0.0746 - mape: 1.6756 - val_loss: 0.1478 - val_mae: 0.1246 - val_mse: 0.0537 - val_mape: 1.2627
# Epoch 28/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.1937 - mae: 0.1702 - mse: 0.0750 - mape: 1.6805 - val_loss: 0.1377 - val_mae: 0.1138 - val_mse: 0.0509 - val_mape: 1.1573
# Epoch 29/200
# 2443/2443 [==============================] - 21s 8ms/step - loss: 0.1933 - mae: 0.1700 - mse: 0.0754 - mape: 1.6801 - val_loss: 0.1275 - val_mae: 0.1040 - val_mse: 0.0490 - val_mape: 1.0664
# Epoch 30/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.1929 - mae: 0.1697 - mse: 0.0753 - mape: 1.6775 - val_loss: 0.1287 - val_mae: 0.1057 - val_mse: 0.0492 - val_mape: 1.0747
# Epoch 31/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.1930 - mae: 0.1700 - mse: 0.0750 - mape: 1.6796 - val_loss: 0.1345 - val_mae: 0.1115 - val_mse: 0.0500 - val_mape: 1.1269
# Epoch 32/200
# 2443/2443 [==============================] - 21s 8ms/step - loss: 0.1914 - mae: 0.1684 - mse: 0.0749 - mape: 1.6656 - val_loss: 0.1307 - val_mae: 0.1079 - val_mse: 0.0507 - val_mape: 1.1028
# Epoch 33/200
# 2443/2443 [==============================] - 21s 9ms/step - loss: 0.1927 - mae: 0.1699 - mse: 0.0756 - mape: 1.6792 - val_loss: 0.1216 - val_mae: 0.0984 - val_mse: 0.0487 - val_mape: 1.0114
# Epoch 34/200
# 2443/2443 [==============================] - 22s 9ms/step - loss: 0.1927 - mae: 0.1700 - mse: 0.0755 - mape: 1.6799 - val_loss: 0.1313 - val_mae: 0.1092 - val_mse: 0.0514 - val_mape: 1.1130
# Epoch 35/200
# 2443/2443 [==============================] - 21s 8ms/step - loss: 0.1924 - mae: 0.1698 - mse: 0.0758 - mape: 1.6796 - val_loss: 0.1422 - val_mae: 0.1196 - val_mse: 0.0525 - val_mape: 1.2099
# Epoch 36/200
# 2443/2443 [==============================] - 19s 8ms/step - loss: 0.1921 - mae: 0.1694 - mse: 0.0749 - mape: 1.6746 - val_loss: 0.1236 - val_mae: 0.1009 - val_mse: 0.0488 - val_mape: 1.0331
# Epoch 37/200
# 2443/2443 [==============================] - 20s 8ms/step - loss: 0.1921 - mae: 0.1694 - mse: 0.0744 - mape: 1.6733 - val_loss: 0.1545 - val_mae: 0.1317 - val_mse: 0.0550 - val_mape: 1.3199
# Epoch 38/200
# 2443/2443 [==============================] - 21s 9ms/step - loss: 0.1921 - mae: 0.1695 - mse: 0.0750 - mape: 1.6753 - val_loss: 0.1263 - val_mae: 0.1037 - val_mse: 0.0492 - val_mape: 1.0623
# Epoch 39/200
# 2443/2443 [==============================] - 22s 9ms/step - loss: 0.1924 - mae: 0.1698 - mse: 0.0752 - mape: 1.6789 - val_loss: 0.1285 - val_mae: 0.1066 - val_mse: 0.0509 - val_mape: 1.0920
# Epoch 40/200
# 2443/2443 [==============================] - 22s 9ms/step - loss: 0.1915 - mae: 0.1692 - mse: 0.0745 - mape: 1.6718 - val_loss: 0.1310 - val_mae: 0.1083 - val_mse: 0.0496 - val_mape: 1.1024
# Epoch 41/200
# 2443/2443 [==============================] - 22s 9ms/step - loss: 0.1925 - mae: 0.1701 - mse: 0.0755 - mape: 1.6815 - val_loss: 0.1324 - val_mae: 0.1101 - val_mse: 0.0505 - val_mape: 1.1163
# Epoch 42/200
# 2443/2443 [==============================] - 22s 9ms/step - loss: 0.1920 - mae: 0.1696 - mse: 0.0754 - mape: 1.6772 - val_loss: 0.1285 - val_mae: 0.1061 - val_mse: 0.0496 - val_mape: 1.0759
# Epoch 43/200
# 2443/2443 [==============================] - 21s 9ms/step - loss: 0.1912 - mae: 0.1689 - mse: 0.0747 - mape: 1.6699 - val_loss: 0.1267 - val_mae: 0.1043 - val_mse: 0.0494 - val_mape: 1.0663
# Epoch 44/200
# 2443/2443 [==============================] - 22s 9ms/step - loss: 0.1908 - mae: 0.1686 - mse: 0.0742 - mape: 1.6667 - val_loss: 0.1246 - val_mae: 0.1022 - val_mse: 0.0484 - val_mape: 1.0402
# Epoch 45/200
# 2443/2443 [==============================] - 22s 9ms/step - loss: 0.1920 - mae: 0.1697 - mse: 0.0748 - mape: 1.6770 - val_loss: 0.1254 - val_mae: 0.1029 - val_mse: 0.0488 - val_mape: 1.0553
# Epoch 46/200
# 2443/2443 [==============================] - 22s 9ms/step - loss: 0.1911 - mae: 0.1687 - mse: 0.0747 - mape: 1.6679 - val_loss: 0.1480 - val_mae: 0.1262 - val_mse: 0.0542 - val_mape: 1.2705
# Epoch 47/200
# 2443/2443 [==============================] - 22s 9ms/step - loss: 0.1923 - mae: 0.1702 - mse: 0.0753 - mape: 1.6824 - val_loss: 0.1435 - val_mae: 0.1211 - val_mse: 0.0525 - val_mape: 1.2128
# Epoch 48/200
# 2443/2443 [==============================] - 22s 9ms/step - loss: 0.1923 - mae: 0.1700 - mse: 0.0751 - mape: 1.6801 - val_loss: 0.1242 - val_mae: 0.1017 - val_mse: 0.0484 - val_mape: 1.0418
# Epoch 49/200
# 2443/2443 [==============================] - 22s 9ms/step - loss: 0.1926 - mae: 0.1703 - mse: 0.0751 - mape: 1.6833 - val_loss: 0.1688 - val_mae: 0.1462 - val_mse: 0.0603 - val_mape: 1.4532
# Epoch 50/200
# 2443/2443 [==============================] - 25s 10ms/step - loss: 0.1925 - mae: 0.1702 - mse: 0.0751 - mape: 1.6823 - val_loss: 0.1414 - val_mae: 0.1196 - val_mse: 0.0547 - val_mape: 1.2065
# Epoch 51/200
# 2443/2443 [==============================] - 26s 11ms/step - loss: 0.1921 - mae: 0.1699 - mse: 0.0753 - mape: 1.6796 - val_loss: 0.1230 - val_mae: 0.1009 - val_mse: 0.0495 - val_mape: 1.0352
# Epoch 52/200
# 2443/2443 [==============================] - 25s 10ms/step - loss: 0.1923 - mae: 0.1701 - mse: 0.0754 - mape: 1.6810 - val_loss: 0.1607 - val_mae: 0.1379 - val_mse: 0.0585 - val_mape: 1.3802
# Epoch 53/200
# 2443/2443 [==============================] - 25s 10ms/step - loss: 0.1915 - mae: 0.1693 - mse: 0.0755 - mape: 1.6744 - val_loss: 0.1238 - val_mae: 0.1015 - val_mse: 0.0494 - val_mape: 1.0408

# %%
model.save(f'../models/{model_version}/spec_photo_model.h5')

# %%
save_history(history, model_version)

# %%
y_pred_full = model.predict(X_test_scaled)
# Out:
# 2094/2094 [==============================] - 3s 2ms/step

# %%
plot_metrics(y_test, y_pred_full)
# Out:
# Evaluation Metrics:
# Mean Absolute Error (MAE): 0.0936
# Root Mean Squared Error (RMSE): 0.1971
# R² Score: 0.9100

# %%
plot_visualizations(history, y_test, y_pred_full)

# %%
df_unseen = pd.read_csv(f"../data/processed/unseen_data.csv")

X_unseen = df_unseen[spectro_cols + photo_cols + generic_cols]
y_unseen = df_unseen[target_col]

# %%
X_unseen_scaled = scaler.transform(X_unseen)

# %%
y_pred_unseen = model.predict(X_unseen_scaled)
# Out:
# 6980/6980 [==============================] - 10s 1ms/step

# %%
plot_metrics(y_unseen, y_pred_unseen)
# Out:
# Evaluation Metrics:
# Mean Absolute Error (MAE): 0.0995
# Root Mean Squared Error (RMSE): 0.4037
# R² Score: 0.6190

# %%
plot_visualizations(history, y_unseen, y_pred_unseen)
