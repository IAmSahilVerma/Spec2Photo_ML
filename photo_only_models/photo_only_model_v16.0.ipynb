# %%
import sys
sys.path.append('../')

# %%
# Enable autoreload for external modules
# %load_ext autoreload
# %autoreload 2

# %%
import os
import json
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras import layers, callbacks, regularizers
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from util import *

# %%
seed_value = 42

os.environ['PYTHONHASHSEED'] = str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# %%
model_version = 'v16.0'
base_model_version = 'v16.0'

# %%
with open('../data_schema_V2.0.json', 'r') as f:
    config = json.load(f)
    
spectro_cols = config['spectro_cols']
photo_cols = config['photometry_cols']
generic_cols = config['generic_cols']
target_col = config['target_col']

# %%
df = pd.read_csv(f"../data/processed/photometry_only.csv")

X = df[photo_cols + generic_cols]
y = df[target_col]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed_value)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
input_shape = X_train_scaled.shape[1]

optimizer = Adam(learning_rate=0.001)

inputs = keras.Input(shape=(input_shape,), name='Input')

# Layer 1
x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001), name='Dense_64')(inputs)
x = layers.Dropout(0.2, name='Dropout_64')(x)

# Layer 2
x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001), name='Dense_128')(x)
x = layers.Dropout(0.2, name='Dropout_128')(x)

# Layer 3
x = layers.Dense(256, kernel_regularizer=regularizers.l2(0.001), name='Dense_256')(x)
x = layers.Dropout(0.2, name='Dropout_256')(x)

# Layer 4
x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001), name='Dense_128_2')(x)
x = layers.Dropout(0.2, name='Dropout_128_2')(x)

# Layer 5
x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001), name='Dense_64_2')(x)
x = layers.Dropout(0.2, name='Dropout_64_2')(x)

# Output layer
outputs = layers.Dense(1, name='Output')(x)

model = keras.Model(inputs=inputs, outputs=outputs, name='Regression_Model')

model.load_weights(f"../models/{base_model_version}/spec_photo_model.h5", by_name=True, skip_mismatch=True)

model.get_layer('Dense_64').trainable = False
model.get_layer('Dense_128').trainable = False
model.get_layer('Dense_256').trainable = False
model.get_layer('Dense_128_2').trainable = True

early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

model.compile(optimizer=optimizer, 
              loss=tf.keras.losses.mean_squared_error, 
              metrics=['mae', 'mse', 'mape'])

model.summary()
# Out:
# WARNING:tensorflow:Skipping loading weights for layer #1 (named Dense_64) due to mismatch in shape for weight Dense_64/kernel:0. Weight expects shape (10, 64). Received saved weight with shape (18, 64)
# WARNING:tensorflow:Skipping loading weights for layer #9 (named Output) due to mismatch in shape for weight Output/kernel:0. Weight expects shape (64, 1). Received saved weight with shape (128, 1)
# Model: "Regression_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 10)]              0
#
#  Dense_64 (Dense)            (None, 64)                704
#
#  Dropout_64 (Dropout)        (None, 64)                0
#
#  Dense_128 (Dense)           (None, 128)               8320
#
#  Dropout_128 (Dropout)       (None, 128)               0
#
#  Dense_256 (Dense)           (None, 256)               33024
#
#  Dropout_256 (Dropout)       (None, 256)               0
#
#  Dense_128_2 (Dense)         (None, 128)               32896
#
#  Dropout_128_2 (Dropout)     (None, 128)               0
#
#  Dense_64_2 (Dense)          (None, 64)                8256
#
#  Dropout_64_2 (Dropout)      (None, 64)                0
#
#  Output (Dense)              (None, 1)                 65
#
# =================================================================
# Total params: 83,265
# Trainable params: 41,217
# Non-trainable params: 42,048
# _________________________________________________________________

# %%
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)
history = model.fit(X_train_scaled, y_train, epochs=200, batch_size=32, validation_split=0.2, verbose=1, callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 3900/3900 [==============================] - 22s 6ms/step - loss: 0.5102 - mae: 0.5281 - mse: 0.4603 - mape: 5.0966 - val_loss: 0.4080 - val_mae: 0.4826 - val_mse: 0.3678 - val_mape: 4.6032
# Epoch 2/200
# 3900/3900 [==============================] - 22s 6ms/step - loss: 0.4442 - mae: 0.4957 - mse: 0.4090 - mape: 4.7958 - val_loss: 0.3810 - val_mae: 0.4624 - val_mse: 0.3496 - val_mape: 4.4651
# Epoch 3/200
# 3900/3900 [==============================] - 22s 6ms/step - loss: 0.4214 - mae: 0.4836 - mse: 0.3920 - mape: 4.6858 - val_loss: 0.3744 - val_mae: 0.4590 - val_mse: 0.3457 - val_mape: 4.4385
# Epoch 4/200
# 3900/3900 [==============================] - 22s 6ms/step - loss: 0.4116 - mae: 0.4780 - mse: 0.3843 - mape: 4.6356 - val_loss: 0.3800 - val_mae: 0.4640 - val_mse: 0.3537 - val_mape: 4.4861
# Epoch 5/200
# 3900/3900 [==============================] - 22s 6ms/step - loss: 0.4063 - mae: 0.4744 - mse: 0.3796 - mape: 4.6029 - val_loss: 0.3771 - val_mae: 0.4573 - val_mse: 0.3506 - val_mape: 4.4527
# Epoch 6/200
# 3900/3900 [==============================] - 22s 6ms/step - loss: 0.4018 - mae: 0.4717 - mse: 0.3751 - mape: 4.5760 - val_loss: 0.3704 - val_mae: 0.4551 - val_mse: 0.3434 - val_mape: 4.4155
# Epoch 7/200
# 3900/3900 [==============================] - 22s 6ms/step - loss: 0.3993 - mae: 0.4693 - mse: 0.3728 - mape: 4.5533 - val_loss: 0.3681 - val_mae: 0.4560 - val_mse: 0.3414 - val_mape: 4.4073
# Epoch 8/200
# 3900/3900 [==============================] - 23s 6ms/step - loss: 0.3980 - mae: 0.4683 - mse: 0.3718 - mape: 4.5452 - val_loss: 0.3711 - val_mae: 0.4594 - val_mse: 0.3450 - val_mape: 4.4324
# Epoch 9/200
# 3900/3900 [==============================] - 22s 6ms/step - loss: 0.3980 - mae: 0.4682 - mse: 0.3720 - mape: 4.5447 - val_loss: 0.3683 - val_mae: 0.4568 - val_mse: 0.3424 - val_mape: 4.4122
# Epoch 10/200
# 3900/3900 [==============================] - 22s 6ms/step - loss: 0.3973 - mae: 0.4675 - mse: 0.3714 - mape: 4.5385 - val_loss: 0.3667 - val_mae: 0.4537 - val_mse: 0.3407 - val_mape: 4.3968
# Epoch 11/200
# 3900/3900 [==============================] - 22s 6ms/step - loss: 0.3971 - mae: 0.4672 - mse: 0.3713 - mape: 4.5364 - val_loss: 0.3708 - val_mae: 0.4604 - val_mse: 0.3450 - val_mape: 4.4334
# Epoch 12/200
# 3900/3900 [==============================] - 22s 6ms/step - loss: 0.3961 - mae: 0.4670 - mse: 0.3703 - mape: 4.5336 - val_loss: 0.3686 - val_mae: 0.4546 - val_mse: 0.3429 - val_mape: 4.4069
# 3900/3900 [==============================] - 39s 10ms/step - loss: 0.3948 - mae: 0.4651 - mse: 0.3684 - mape: 4.5152 - val_loss: 0.3615 - val_mae: 0.4483 - val_mse: 0.3351 - val_mape: 4.3459
# Epoch 27/200
# 3900/3900 [==============================] - 38s 10ms/step - loss: 0.3943 - mae: 0.4645 - mse: 0.3680 - mape: 4.5094 - val_loss: 0.3778 - val_mae: 0.4541 - val_mse: 0.3518 - val_mape: 4.4308
# Epoch 28/200
# 3900/3900 [==============================] - 39s 10ms/step - loss: 0.3956 - mae: 0.4653 - mse: 0.3693 - mape: 4.5177 - val_loss: 0.3634 - val_mae: 0.4489 - val_mse: 0.3370 - val_mape: 4.3568
# Epoch 29/200
# 3900/3900 [==============================] - 39s 10ms/step - loss: 0.3952 - mae: 0.4650 - mse: 0.3688 - mape: 4.5148 - val_loss: 0.3642 - val_mae: 0.4491 - val_mse: 0.3380 - val_mape: 4.3629
# Epoch 30/200
# 3900/3900 [==============================] - 39s 10ms/step - loss: 0.3940 - mae: 0.4646 - mse: 0.3676 - mape: 4.5106 - val_loss: 0.3631 - val_mae: 0.4478 - val_mse: 0.3367 - val_mape: 4.3509
# Epoch 31/200
# 3900/3900 [==============================] - 39s 10ms/step - loss: 0.3942 - mae: 0.4640 - mse: 0.3677 - mape: 4.5057 - val_loss: 0.3640 - val_mae: 0.4524 - val_mse: 0.3377 - val_mape: 4.3702
# Epoch 32/200
# 3900/3900 [==============================] - 38s 10ms/step - loss: 0.3939 - mae: 0.4639 - mse: 0.3674 - mape: 4.5047 - val_loss: 0.3679 - val_mae: 0.4571 - val_mse: 0.3414 - val_mape: 4.4012
# Epoch 33/200
# 3900/3900 [==============================] - 39s 10ms/step - loss: 0.3950 - mae: 0.4646 - mse: 0.3685 - mape: 4.5108 - val_loss: 0.3728 - val_mae: 0.4527 - val_mse: 0.3465 - val_mape: 4.4048
# Epoch 34/200
# 3900/3900 [==============================] - 40s 10ms/step - loss: 0.3945 - mae: 0.4645 - mse: 0.3680 - mape: 4.5099 - val_loss: 0.3647 - val_mae: 0.4539 - val_mse: 0.3382 - val_mape: 4.3721
# Epoch 35/200
# 3900/3900 [==============================] - 41s 10ms/step - loss: 0.3948 - mae: 0.4650 - mse: 0.3685 - mape: 4.5143 - val_loss: 0.3691 - val_mae: 0.4545 - val_mse: 0.3427 - val_mape: 4.3982
# Epoch 36/200
# 3896/3900 [============================>.] - ETA: 0s - loss: 0.3935 - mae: 0.4644 - mse: 0.3672 - mape: 4.5081Restoring model weights from the end of the best epoch: 26.
# 3900/3900 [==============================] - 36s 9ms/step - loss: 0.3935 - mae: 0.4643 - mse: 0.3673 - mape: 4.5080 - val_loss: 0.3658 - val_mae: 0.4543 - val_mse: 0.3395 - val_mape: 4.3831
# Epoch 36: early stopping

# %%
model.save(f"../models/{model_version}/photo_only_model.h5")

# %%
save_history(history, model_version, history_name='history_photo_only')

# %%
y_pred = model.predict(X_test_scaled)
# Out:
# 2090/2090 [==============================] - 3s 2ms/step

# %%
plot_metrics(y_test, y_pred)
# Out:
# Evaluation Metrics:
# Mean Absolute Error (MAE): 0.4523
# Root Mean Squared Error (RMSE): 0.5890
# R² Score: 0.1818

# %%
plot_visualizations(y_test, y_pred, z_values=X_test['z'], history=history)
