# %%
import sys
sys.path.append('../')

# %%
# Enable autoreload for external modules
# %load_ext autoreload
# %autoreload 2

# %%
import os
import json
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras import layers, callbacks, regularizers
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from util import *

# %%
seed_value = 42

os.environ['PYTHONHASHSEED'] = str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# %%
model_version = 'v16.0'

# %%
with open('../data_schema_V2.0.json', 'r') as f:
    config = json.load(f)
    
spectro_cols = config['spectro_cols']
photo_cols = config['photometry_cols']
generic_cols = config['generic_cols']
target_col = config['target_col']

# %%
df = pd.read_csv(f"../data/processed/spectrometry_photometry.csv")

X = df[photo_cols]
y = df[target_col]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed_value)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
input_shape = X_train_scaled.shape[1]

optimizer = Adam(learning_rate=0.001)

inputs = keras.Input(shape=(input_shape,), name='Input')

# Layer 1
x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001), name='Dense_64')(inputs)
x = layers.Dropout(0.2, name='Dropout_64')(x)

# Layer 2
x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001), name='Dense_128')(x)
x = layers.Dropout(0.2, name='Dropout_128')(x)

# Layer 3
x = layers.Dense(256, kernel_regularizer=regularizers.l2(0.001), name='Dense_256')(x)
x = layers.Dropout(0.2, name='Dropout_256')(x)

# Layer 4
x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001), name='Dense_128_2')(x)
x = layers.Dropout(0.2, name='Dropout_128_2')(x)

# Output layer
outputs = layers.Dense(1, name='Output')(x)

model = keras.Model(inputs=inputs, outputs=outputs, name='Regression_Model')
early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

model.compile(optimizer=optimizer, 
              loss=tf.keras.losses.mean_squared_error, 
              metrics=['mae', 'mse', 'mape'])

model.summary()
# Out:
# Model: "Regression_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 8)]               0
#
#  Dense_64 (Dense)            (None, 64)                576
#
#  Dropout_64 (Dropout)        (None, 64)                0
#
#  Dense_128 (Dense)           (None, 128)               8320
#
#  Dropout_128 (Dropout)       (None, 128)               0
#
#  Dense_256 (Dense)           (None, 256)               33024
#
#  Dropout_256 (Dropout)       (None, 256)               0
#
#  Dense_128_2 (Dense)         (None, 128)               32896
#
#  Dropout_128_2 (Dropout)     (None, 128)               0
#
#  Output (Dense)              (None, 1)                 129
#
# =================================================================
# Total params: 74,945
# Trainable params: 74,945
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    X_train_scaled, y_train,
    validation_split=0.5,
    epochs=200,
    batch_size=32,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/200
# 2438/2438 [==============================] - 19s 8ms/step - loss: 2.3810 - mae: 0.9324 - mse: 2.0323 - mape: 8.8461 - val_loss: 0.3953 - val_mae: 0.2760 - val_mse: 0.1417 - val_mape: 2.6841
# Epoch 2/200
# 2438/2438 [==============================] - 18s 7ms/step - loss: 0.8812 - mae: 0.6632 - mse: 0.6971 - mape: 6.3074 - val_loss: 0.2669 - val_mae: 0.2763 - val_mse: 0.1418 - val_mape: 2.6617
# Epoch 3/200
# 2438/2438 [==============================] - 17s 7ms/step - loss: 0.7003 - mae: 0.6211 - mse: 0.6155 - mape: 5.9106 - val_loss: 0.1877 - val_mae: 0.2589 - val_mse: 0.1337 - val_mape: 2.5466
# Epoch 4/200
# 2438/2438 [==============================] - 17s 7ms/step - loss: 0.5818 - mae: 0.5833 - mse: 0.5436 - mape: 5.5530 - val_loss: 0.1677 - val_mae: 0.2609 - val_mse: 0.1392 - val_mape: 2.5723
# Epoch 5/200
# 2438/2438 [==============================] - 17s 7ms/step - loss: 0.4989 - mae: 0.5444 - mse: 0.4751 - mape: 5.1871 - val_loss: 0.1530 - val_mae: 0.2664 - val_mse: 0.1332 - val_mape: 2.5953
# Epoch 6/200
# 2438/2438 [==============================] - 16s 7ms/step - loss: 0.4385 - mae: 0.5108 - mse: 0.4195 - mape: 4.8704 - val_loss: 0.1456 - val_mae: 0.2717 - val_mse: 0.1284 - val_mape: 2.6160
# Epoch 7/200
# 2438/2438 [==============================] - 17s 7ms/step - loss: 0.3886 - mae: 0.4794 - mse: 0.3716 - mape: 4.5763 - val_loss: 0.1347 - val_mae: 0.2450 - val_mse: 0.1184 - val_mape: 2.4020
# Epoch 8/200
# 2438/2438 [==============================] - 17s 7ms/step - loss: 0.3497 - mae: 0.4536 - mse: 0.3338 - mape: 4.3337 - val_loss: 0.1443 - val_mae: 0.2727 - val_mse: 0.1289 - val_mape: 2.6189
# Epoch 9/200
# 2438/2438 [==============================] - 17s 7ms/step - loss: 0.3232 - mae: 0.4344 - mse: 0.3075 - mape: 4.1527 - val_loss: 0.1357 - val_mae: 0.2484 - val_mse: 0.1199 - val_mape: 2.4348
# Epoch 10/200
# 2438/2438 [==============================] - 17s 7ms/step - loss: 0.2882 - mae: 0.4071 - mse: 0.2723 - mape: 3.8965 - val_loss: 0.1452 - val_mae: 0.2732 - val_mse: 0.1290 - val_mape: 2.6184
# Epoch 11/200
# 2438/2438 [==============================] - 17s 7ms/step - loss: 0.2664 - mae: 0.3893 - mse: 0.2504 - mape: 3.7297 - val_loss: 0.1399 - val_mae: 0.2601 - val_mse: 0.1234 - val_mape: 2.5033
# Epoch 12/200
# 2438/2438 [==============================] - 16s 7ms/step - loss: 0.2426 - mae: 0.3700 - mse: 0.2264 - mape: 3.5476 - val_loss: 0.1263 - val_mae: 0.2399 - val_mse: 0.1104 - val_mape: 2.3275
# Epoch 13/200
# 2438/2438 [==============================] - 17s 7ms/step - loss: 0.2268 - mae: 0.3544 - mse: 0.2107 - mape: 3.4023 - val_loss: 0.1244 - val_mae: 0.2347 - val_mse: 0.1084 - val_mape: 2.2920
# Epoch 14/200
# 2438/2438 [==============================] - 17s 7ms/step - loss: 0.2105 - mae: 0.3394 - mse: 0.1941 - mape: 3.2618 - val_loss: 0.1233 - val_mae: 0.2377 - val_mse: 0.1071 - val_mape: 2.3093
# Epoch 15/200
# 2438/2438 [==============================] - 17s 7ms/step - loss: 0.1967 - mae: 0.3249 - mse: 0.1802 - mape: 3.1272 - val_loss: 0.1310 - val_mae: 0.2509 - val_mse: 0.1145 - val_mape: 2.4276
# Epoch 16/200
# 2438/2438 [==============================] - 17s 7ms/step - loss: 0.1851 - mae: 0.3140 - mse: 0.1684 - mape: 3.0243 - val_loss: 0.1257 - val_mae: 0.2356 - val_mse: 0.1089 - val_mape: 2.2993
# Epoch 17/200
# 2438/2438 [==============================] - 24s 10ms/step - loss: 0.1771 - mae: 0.3030 - mse: 0.1603 - mape: 2.9228 - val_loss: 0.1252 - val_mae: 0.2410 - val_mse: 0.1082 - val_mape: 2.3347
# Epoch 18/200
# 2438/2438 [==============================] - 25s 10ms/step - loss: 0.1683 - mae: 0.2934 - mse: 0.1513 - mape: 2.8336 - val_loss: 0.1251 - val_mae: 0.2348 - val_mse: 0.1078 - val_mape: 2.2915
# Epoch 19/200
# 2438/2438 [==============================] - 24s 10ms/step - loss: 0.1626 - mae: 0.2861 - mse: 0.1455 - mape: 2.7661 - val_loss: 0.1269 - val_mae: 0.2382 - val_mse: 0.1093 - val_mape: 2.3249
# Epoch 20/200
# 2438/2438 [==============================] - 23s 10ms/step - loss: 0.1572 - mae: 0.2797 - mse: 0.1400 - mape: 2.7071 - val_loss: 0.1237 - val_mae: 0.2328 - val_mse: 0.1063 - val_mape: 2.2708
# Epoch 21/200
# 2438/2438 [==============================] - 23s 9ms/step - loss: 0.1546 - mae: 0.2759 - mse: 0.1373 - mape: 2.6727 - val_loss: 0.1297 - val_mae: 0.2375 - val_mse: 0.1126 - val_mape: 2.3329
# Epoch 22/200
# 2438/2438 [==============================] - 22s 9ms/step - loss: 0.1518 - mae: 0.2718 - mse: 0.1346 - mape: 2.6368 - val_loss: 0.1278 - val_mae: 0.2427 - val_mse: 0.1108 - val_mape: 2.3576
# Epoch 23/200
# 2438/2438 [==============================] - 23s 9ms/step - loss: 0.1517 - mae: 0.2706 - mse: 0.1346 - mape: 2.6265 - val_loss: 0.1264 - val_mae: 0.2364 - val_mse: 0.1088 - val_mape: 2.3053
# Epoch 24/200
# 2438/2438 [==============================] - 23s 9ms/step - loss: 0.1500 - mae: 0.2687 - mse: 0.1333 - mape: 2.6102 - val_loss: 0.1337 - val_mae: 0.2532 - val_mse: 0.1170 - val_mape: 2.4492
# Epoch 25/200
# 2438/2438 [==============================] - 23s 9ms/step - loss: 0.1494 - mae: 0.2680 - mse: 0.1330 - mape: 2.6041 - val_loss: 0.1260 - val_mae: 0.2359 - val_mse: 0.1098 - val_mape: 2.3060
# Epoch 26/200
# 2438/2438 [==============================] - 22s 9ms/step - loss: 0.1493 - mae: 0.2680 - mse: 0.1333 - mape: 2.6050 - val_loss: 0.1288 - val_mae: 0.2376 - val_mse: 0.1135 - val_mape: 2.3346
# Epoch 27/200
# 2438/2438 [==============================] - 23s 9ms/step - loss: 0.1489 - mae: 0.2676 - mse: 0.1332 - mape: 2.6007 - val_loss: 0.1255 - val_mae: 0.2364 - val_mse: 0.1103 - val_mape: 2.3117
# Epoch 28/200
# 2438/2438 [==============================] - 22s 9ms/step - loss: 0.1487 - mae: 0.2684 - mse: 0.1334 - mape: 2.6087 - val_loss: 0.1447 - val_mae: 0.2748 - val_mse: 0.1294 - val_mape: 2.6364
# Epoch 29/200
# 2438/2438 [==============================] - 23s 9ms/step - loss: 0.1484 - mae: 0.2679 - mse: 0.1333 - mape: 2.6048 - val_loss: 0.1332 - val_mae: 0.2523 - val_mse: 0.1181 - val_mape: 2.4477
# Epoch 30/200
# 2438/2438 [==============================] - 22s 9ms/step - loss: 0.1487 - mae: 0.2681 - mse: 0.1337 - mape: 2.6058 - val_loss: 0.1289 - val_mae: 0.2474 - val_mse: 0.1144 - val_mape: 2.4009
# Epoch 31/200
# Epoch 59/200
# 2438/2438 [==============================] - 33s 14ms/step - loss: 0.1460 - mae: 0.2673 - mse: 0.1331 - mape: 2.5994 - val_loss: 0.1289 - val_mae: 0.2467 - val_mse: 0.1159 - val_mape: 2.3955
# Epoch 60/200
# 2438/2438 [==============================] - 34s 14ms/step - loss: 0.1459 - mae: 0.2670 - mse: 0.1330 - mape: 2.5961 - val_loss: 0.1277 - val_mae: 0.2464 - val_mse: 0.1146 - val_mape: 2.3970
# Epoch 61/200
# 2438/2438 [==============================] - 33s 14ms/step - loss: 0.1468 - mae: 0.2689 - mse: 0.1339 - mape: 2.6140 - val_loss: 0.1310 - val_mae: 0.2468 - val_mse: 0.1178 - val_mape: 2.4005
# Epoch 62/200
# 2438/2438 [==============================] - 33s 14ms/step - loss: 0.1457 - mae: 0.2673 - mse: 0.1329 - mape: 2.5991 - val_loss: 0.1241 - val_mae: 0.2385 - val_mse: 0.1114 - val_mape: 2.3287
# Epoch 63/200
# 2438/2438 [==============================] - 33s 13ms/step - loss: 0.1456 - mae: 0.2675 - mse: 0.1328 - mape: 2.6001 - val_loss: 0.1236 - val_mae: 0.2341 - val_mse: 0.1109 - val_mape: 2.2962
# Epoch 64/200
# 2438/2438 [==============================] - 33s 14ms/step - loss: 0.1459 - mae: 0.2674 - mse: 0.1330 - mape: 2.5998 - val_loss: 0.1252 - val_mae: 0.2366 - val_mse: 0.1121 - val_mape: 2.3119
# Epoch 65/200
# 2438/2438 [==============================] - 35s 14ms/step - loss: 0.1465 - mae: 0.2685 - mse: 0.1337 - mape: 2.6104 - val_loss: 0.1310 - val_mae: 0.2481 - val_mse: 0.1183 - val_mape: 2.4219

# %%
model.save(f'../models/{model_version}/photo_no_redshift_no_trasnfer_model.h5')

# %%
save_history(history, model_version, history_name='history_photo_no_redshift_no_transfer')

# %%
history = load_history(model_version, history_name='history_photo_no_redshift_no_transfer')

# %%
model = load_model(model_version, model_name='photo_no_redshift_no_trasnfer_model')

# %%
y_pred_full = model.predict(X_test_scaled)
# Out:
# 2090/2090 [==============================] - 4s 2ms/step

# %%
plot_metrics(y_test, y_pred_full)
# Out:
# Evaluation Metrics:
# Mean Absolute Error (MAE): 0.2348
# Root Mean Squared Error (RMSE): 0.3361
# R² Score: 0.7381

# %%
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.3, random_state=seed_value)
sns.scatterplot(y=y_test.iloc[:, 0].values.ravel(), x=X_test['z'])
# Out:
# <Axes: xlabel='z'>

# %%
sns.scatterplot(y=y_pred_full.ravel(), x=X_test['z'])
# Out:
# <Axes: xlabel='z'>

# %%
plot_visualizations(y_test, y_pred_full, z_values=X_test['z'], history=history)

# %%
df_unseen = pd.read_csv(f"../data/processed/unseen_data.csv")

X_unseen = df_unseen[photo_cols + generic_cols]
y_unseen = df_unseen[target_col]

# %%
X_unseen_scaled = scaler.transform(X_unseen)

# %%
y_pred_unseen = model.predict(X_unseen_scaled)
# Out:
# 6965/6965 [==============================] - 9s 1ms/step

# %%
plot_metrics(y_unseen, y_pred_unseen)
# Out:
# Evaluation Metrics:
# Mean Absolute Error (MAE): 0.0830
# Root Mean Squared Error (RMSE): 0.1543
# R² Score: 0.9433

# %%
plot_visualizations(y_unseen, y_pred_unseen, z_values=X_unseen['z'])
